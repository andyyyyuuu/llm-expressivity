# %% [markdown]
# Clone the repo from Github if needed.

# %%
# !git clone https://github.com/AndyyyYuuu/llm-expressivity.git
# %cd llm-expressivity

# %% [markdown]
# `.env` is required. See `.env.example` for environment variables.

# %%
# This is for the virtual machines I used; replace with pip from your own env / venv
# !/venv/main/bin/pip install -r requirements.txt

# %%
from datetime import datetime
import importlib

import distprompt.modules as modules
import distprompt.sweep as sweep
import distprompt.targets as targets

# %%
importlib.reload(sweep)
importlib.reload(modules)
importlib.reload(targets)
save_path = f"saves/{datetime.now().strftime('%Y%m%d%H%M')}_linsoftmax.csv"

# Choose from the following interventions: 
#module = modules.LayerIntervention(layer=5, prefix_length=5)
#module = modules.EmbedIntervention(prefix_length=5)
#module = modules.PostNormIntervention(prefix_length=5, input_size)
module = modules.LinearSoftmax(prefix_length=5, input_size=2048, vocab_size=128256)

# Choose from the following target generating methods: 
targets = targets.OptimEntropyGrid(module, seed=216, is_outlier=False)

sweep.run_experiment(str(save_path), module, targets)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# Generating targets: 100%|██████████| 236/236 [02:09<00:00,  1.82it/s]
# saved 236 targets to saves/optimentropygrid_vanilla_128256_216.pt
# sweeping targets:   0%|          | 0/236 [00:00<?, ?it/s]
# training H=0.00:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.05:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.10:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.15:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.20:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.25:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.30:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.35:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.40:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.45:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.50:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.55:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.60:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.65:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.70:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.75:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.80:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.85:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.90:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=0.95:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.00:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.05:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.10:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.15:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.20:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.25:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.30:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.35:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.40:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.45:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.50:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.55:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.60:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.65:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.70:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.75:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.80:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.85:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.90:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=1.95:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.00:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.05:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.10:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.15:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.20:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.25:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.30:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.35:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.40:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.45:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.50:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.55:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.60:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.65:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.70:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.75:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.80:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.85:   0%|          | 0/500 [00:00<?, ?it/s]
# training H=2.90:   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 15
#      11
#      12 # Choose from the following target generating methods:
#      13 targets = targets.OptimEntropyGrid(module, seed=216, is_outlier=False)
#      14
# ---> 15 sweep.run_experiment(str(save_path), module, targets)
#
# File ~/Documents/GitHub/llm-expressivity/distprompt/sweep.py:29, in run_experiment(save_path, module, targets)
#      27 for i, (H, target) in enumerate(tqdm(targets, desc=f"sweeping targets")):
#      28     set_seed(int(os.getenv("TRAINING_SEED", "216")) + i)
# ---> 29     best_prompt, best_loss, early_stopped = tune_soft_prompt(module, H, target, lr=0.1, max_epochs=500, early_stop_patience=20, log_losses=False)
#      30     writer.writerow([H, best_loss, int(early_stopped)])
#      31     f.flush()
#
# File ~/Documents/GitHub/llm-expressivity/distprompt/train.py:55, in tune_soft_prompt(module, target_entropy, target_logits, lr, max_epochs, early_stop_patience, log_losses)
#      52 if log_losses and epoch % 10 == 0:
#      53     tqdm.write(f"Epoch {epoch}, Loss: {loss.item()}")
# ---> 55 if loss.item() < best_loss:
#      56     best_loss = loss.item()
#      57     best_prompt = soft_prompt.detach().clone()
#
# KeyboardInterrupt:
